# %% [markdown]
# ## Pandas
#
# > ```index```
# >
# > + [10: インストールからSeriesの使い方](#10:-インストールからSeriesの使い方)
# > + [11: DataFrameを作る CSVファイルを読み込む](#11:-DataFrameを作る-CSVファイルを読み込む)
# > + [12: DataFrameの基本的操作](#12:-DataFrameの基本的操作)
# > + []()
# > + []()
# > + []()
# > + []()
# > + []()
# > + []()
# > + []()
#
#
# > `cf.`
# >
# > + [データサイエンスのためのPython入門⑩〜PandasインストールからSeriesの使い方〜](https://datawokagaku.com/pandas_series/)
# > + [データサイエンスのためのPython入門11〜PandasのDataFrameを作る．CSVファイルを読み込む〜](https://datawokagaku.com/dataframe/)
# > + [データサイエンスのためのPython入門12〜DataFrameの基本的な使い方(head, describe, Seriesの取得など)〜](https://datawokagaku.com/dataframe_howto_1/)
# > + [データサイエンスのためのPython入門13〜DataFrameのフィルタ操作の基本(超重要)〜](https://datawokagaku.com/dataframe_filter/)
# > + [データサイエンスのためのPython入門14〜DataFrameの欠損値NaNに対応する〜](https://datawokagaku.com/dataframe_nan/)
# > + [データサイエンスのためのPython入門15〜DataFrameのgroupbyをマスターする〜](https://datawokagaku.com/dataframe_groupby/)
# > + [データサイエンスのためのPython入門16〜DataFrameのテーブル結合を完全解説(merge, join, concat)〜](https://datawokagaku.com/dataframe_merge/)
# > + [データサイエンスのためのPython入門17〜DataFrameの重要関数(apply, unique, value_counts)を超わかりやすく解説〜](https://datawokagaku.com/dataframe_apply/)
# > + [データサイエンスのためのPython入門18〜DataFrameのその他頻出関数(to_csv, iterrows, sort_values)を解説〜](https://datawokagaku.com/dataframe_func1/)
# > + [データサイエンスのためのPython入門19〜DataFrameのその他頻出関数(pivot_table, xs)を解説〜](https://datawokagaku.com/dataframe_func2/)

# %% [markdown]
# ### 10: インストールからSeriesの使い方
# > Pandasはデータ操作や解析を目的として作られたPythonライブラリで、NumPyをなかで使っている。<br>
# > とりわけ表形式のデータ処理が得意で、エクセルで処理するようなことをPythonでできる。

# %% [markdown]
# #### | Pandasをimport

# %%
import pandas as pd

# %%
# Pandasの所在確認
pd.__file__
# Out:
# '/Users/t/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/__init__.py'

# %% [markdown]
# #### | Seriesを使う
# > PandasにあるSeriesというクラスを使う。<br>
# > Series：表形式のデータの各行、カラムを切り取ったデータを表すデータ形式
#
# <img src='https://datawokagaku.com/wp-content/uploads/2020/01/dataframe_yougo.png' width=65%>
#
# > + Table(テーブル):表形式のデータ
# > + header(ヘッダー):表の一番うえに並んでいるの
# > + column(カラム):ヘッダーを構成する一つ一つ
# > + row(ロウ):表には色々なデータがずらっとヘッダーのカラム順に合わせて並んでいる一行一行
# > + recode(レコード):行のこと
#
# <img src='https://datawokagaku.com/wp-content/uploads/2020/01/dataframe_series.png' width=65%>
#
# > + DataFrame(データフレーム):Pandasでは、この表をDataFrameというデータ構造で扱う。
# > + Series(シリーズ):各行をSeriesというデータ構造を使って扱う。（縦に切り取ってもSeriesになる）
# >
# >（つまり，Seriesというデータ構造が集まってDataFrameというデータ構造になるイメージ）

# %% [markdown]
# ##### - dict → Serise

# %%
# 作り方は簡単で、dictionaryを作ってそれをpd.Series()に入れるだけ!
data = {
    'name':'John',
    'sex':'mael',
    'age':22
}

john_s = pd.Series(data)
print(john_s)
print('\nJohns age is {}.'.format(john_s['age']))
type(john_s)
# Out:
# name    John
# sex     mael
# age       22
# dtype: object
#
# Johns age is 22.
# pandas.core.series.Series

# %% [markdown]
# ##### - ndarray → Serise

# %%
# NumPy Arraysを使って作ることも可能
import numpy as np
array = np.array([100, 200, 300])
array = pd.Series(array)
print(array)
type(array)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64
# pandas.core.series.Series

# %%
array = array.rename(index={0 : 'a', 1 : 'b', 2 : 'c'})
print(array)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# ### 11: DataFrameを作る CSVファイルを読み込む

# %% [markdown]
# #### | DataFrameの作り方

# %% [markdown]
# ##### - ndarray → df

# %%
import pandas as pd 
import numpy as np

# %%
ndarray = np.random.randint(5, size=(5, 4))
pd.DataFrame(data=ndarray)
# Out:
#    0  1  2  3
# 0  3  2  1  4
# 1  2  3  2  0
# 2  2  2  2  0
# 3  4  3  4  3
# 4  0  0  1  1

# %%
# header index を変更
columns = ['a', 'b', 'c', 'd']
index = np.arange(0, 50, 10)
pd.DataFrame(data=ndarray, index=index, columns=columns)
# Out:
#     a  b  c  d
# 0   3  2  1  4
# 10  2  3  2  0
# 20  2  2  2  0
# 30  4  3  4  3
# 40  0  0  1  1

# %% [markdown]
# ##### - dict → df

# %%
data1 = {
    'name':'John',
    'sex':'male',
    'age':22
}
data2 = {
    'name':'Zack',
    'sex':'male',
    'age':30
}
data3 = {
    'name':'Emily',
    'sex':'female',
    'age':32
}
pd.DataFrame([data1, data2, data3])

# %% [markdown]
# ##### - 各.file → df

# %%
pd.read_csv('url')
# Out:
# --------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-9-e21447385aae> in <module>
# ----> 1 pd.read_csv('url')
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'url'

# %% [markdown]
# ### 12: DataFrameの基本的操作

# %%
import pandas as pd
df = pd.read_csv('input/train.csv')

# %% [markdown]
# ##### - .head()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ##### -.tail()

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ##### -.describe()

# %%
#統計量確認
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ##### - .columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### | [](ブラケット)特定カラム抽出（Series）

# %%
age_df = df['Age']
age_df
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(age_df)
# Out:
# pandas.core.series.Series

# %%
df[['Age', 'Parch', 'Fare']].head()
# Out:
#     Age  Parch     Fare
# 0  22.0      0   7.2500
# 1  38.0      0  71.2833
# 2  26.0      0   7.9250
# 3  35.0      0  53.1000
# 4  35.0      0   8.0500

# %% [markdown]
# ##### -.iloc[int]
# (index location)

# %% [markdown]
# >```memo```
# >
# > 基本はカラムは文字列，indexは数値になると思います.<br>
# > たまにindexにID（タイタニックでいうと PassengerId ）を指定することもありますが,<br>
# > 行の取得にはほとんどの場合 ```.iloc[] ```を使います． 私は滅多に ```loc[] ```は使わないです．<br>
# > カラムはできるだけ意味のある文字列にしてください． 意味を持たない数値はややこしいのでやめましょう．

# %%
df.iloc[888]
# Out:
# PassengerId                                         889
# Survived                                              0
# Pclass                                                3
# Name           Johnston, Miss. Catherine Helen "Carrie"
# Sex                                              female
# Age                                                 NaN
# SibSp                                                 1
# Parch                                                 2
# Ticket                                       W./C. 6607
# Fare                                              23.45
# Cabin                                               NaN
# Embarked                                              S
# Name: 888, dtype: object

# %%
df.iloc[888]['Age']
# Out:
# nan

# %%
# NaNというのはnp.nanでありNoneではないことに注意!!!
import numpy as np
np.isnan(df.iloc[888]['Age'])
# Out:
# True

# %%
df.iloc[888]['Age'] is None
# Out:
# False

# %%
df2 = pd.read_csv('input/train.csv').iloc[5:10] # Slicing
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %% [markdown]
# ##### - .drop()
# > 複数のカラムを落としたい場合はカラムをリストにして渡してください．<br>
# > また， dropしても元のdfは変更されません．
#
# > `Cf.`
# > + []()

# %%
df2.drop(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
df2.drop('Age', axis=1)
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  SibSp  Parch  \
# 5                                   Moran, Mr. James    male      0      0
# 6                            McCarthy, Mr. Timothy J    male      0      0
# 7                     Palsson, Master. Gosta Leonard    male      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female      1      0
#
#    Ticket     Fare Cabin Embarked
# 5  330877   8.4583   NaN        Q
# 6   17463  51.8625   E46        S
# 7  349909  21.0750   NaN        S
# 8  347742  11.1333   NaN        S
# 9  237736  30.0708   NaN        C

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
df2 = df2.drop(['Age', 'Parch'], axis=1) #元のdfを上書きする

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  SibSp  Ticket  \
# 5                                   Moran, Mr. James    male      0  330877
# 6                            McCarthy, Mr. Timothy J    male      0   17463
# 7                     Palsson, Master. Gosta Leonard    male      3  349909
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female      0  347742
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female      1  237736
#
#       Fare Cabin Embarked
# 5   8.4583   NaN        Q
# 6  51.8625   E46        S
# 7  21.0750   NaN        S
# 8  11.1333   NaN        S
# 9  30.0708   NaN        C

# %% [markdown]
# ##### - （df上書きパターン）
#
# >```Python
# ># df上書きパターン１ : inplace=True
# >df = pd.read_csv('train.csv')
# >df.drop(['Age', 'Cabin'], axis=1, inplace=True)
# >
# ># df上書きパターン２ : 同名変数に再代入
# >df = pd.read_csv('train.csv')
# >df = df.drop(['Age', 'Cabin'], axis=1)
# >```
#
# >```memo```
# >
# > 私は後者を使います． <br>
# > 理由は， ぱっと見でわかるしデータサイエンスではよく使う書き方だからです．<br>
# > 他のプログラミング言語を勉強した人からすると， 後者は違和感のある書き方だと思います．<br>
# > なるべく結果は違う変数にして変数名を変えて意味を持たせることが多いと思います．<br>
# > 例えば df_drop という変数名にしたりとか...<br>
# > しかし， データサイエンスでは一つの変数が巨大なメモリを使っているケースが多いです．<br>
# >
# > タイタニックのデータは練習用なので小さいですが，実業務では普通に1万レコードとかになったりします．<br>
# > 大きなデータを複数のメモリでコピーしていくとすぐに`メモリリーク`(メモリ不足)を起こしてしまうので， 同じメモリを使いまわすのが定石です．<br>
# > (ここではdfというオブジェクトを使い回しています．)

# %% [markdown]
# ### 13: DataFrameのフィルタ操作の基本(超重要)

# %%
import pandas as pd
df = pd.read_csv('input/train.csv')

# %% [markdown]
# #### | (超重要）特定条件フィルタ(filter)

# %%
# 条件付きでSeriesを取得
df['Survived']==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
# df[filterの条件]で， ある条件に該当したレコードだけが返ってきます．(SQLでいうwhere句のような)
filter = df['Survived']==1
df[filter]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
#
# [342 rows x 12 columns]

# %%
df[filter].describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  290.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.343690    0.473684    0.464912
# std     252.358840       0.0    0.863321   14.950952    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  342.000000
# mean    48.395408
# std     66.596998
# min      0.000000
# 25%     12.475000
# 50%     26.000000
# 75%     57.000000
# max    512.329200

# %% [markdown]
# >```Python
# ># 60才以上のレコードに絞る
# >fill_age60 = df['Age']>=60
# >
# ># 1stクラスのレコードに絞る
# >fill_pclass = df['Pclass']==1
# >
# ># 女性のレコードに絞る
# >fill_sex = df['Sex'] == 'female'
# >```

# %% [markdown]
# ##### - ()&() , ()|()
# > 複数条件フィルタ<br>
# > Pythonだとandやorを使って条件を作りますが，<br>
# > DataFrameのフィルタ操作では `&` と `|` であることに注意!

# %%
# 60歳以上の女性のデータフレーム
df[(df['Age']>=60) & (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 275      0   13502  77.9583    D7        S
# 366      0  110813  75.2500   D37        C
# 483      0    4134   9.5875   NaN        S
# 829      0  113572  80.0000   B28      NaN

# %%
# 1stクラスの人、もしくは10歳未満の子どものデータフレーム
df[(df['Pclass']==1) | (df['Age']<10)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 10            11         1       3
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 7        1    349909  21.0750          NaN        S
# 10       1   PP 9549  16.7000           G6        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [275 rows x 12 columns]

# %% [markdown]
# ##### - ~ （スクィグル）
# > *NOT演算フィルタ*<br>
# > 条件の真偽が逆転します(NOT演算, inversionという．)<br>
# > これは特に「値がbooleanのカラムでフィルタする時」によく使う。

# %%
# e.g. Survivedが真偽値の場合
data = [
    {'Name':'John', 'Survived':True},
    {'Name':'Emily', 'Survived':False},
    {'Name':'Ben', 'Survived':True},
]
df = pd.DataFrame(data)
df
# Out:
#     Name  Survived
# 0   John      True
# 1  Emily     False
# 2    Ben      True

# %%
df[df['Survived']==True] #値は既にBoolのため、==Trueの場合は省略可能
# Out:
#    Name  Survived
# 0  John      True
# 2   Ben      True

# %%
f = df[df['Survived']==False]
s = df[~df['Survived']]
print(f, '\n', s)
# Out:
#     Name  Survived
# 1  Emily     False
#      Name  Survived
# 1  Emily     False

# %% [markdown]
# #### | index変更

# %% [markdown]
# ##### - .reset_index()
# > 再度indexを割り振る

# %%
df2 = pd.read_csv('input/train.csv')
df2 = df2[df2['Sex']=='male']
df2.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
df2 = df2.reset_index()
df2.head()
# Out:
#    index  PassengerId  Survived  Pclass                            Name   Sex  \
# 0      0            1         0       3         Braund, Mr. Owen Harris  male
# 1      4            5         0       3        Allen, Mr. William Henry  male
# 2      5            6         0       3                Moran, Mr. James  male
# 3      6            7         0       1         McCarthy, Mr. Timothy J  male
# 4      7            8         0       3  Palsson, Master. Gosta Leonard  male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  35.0      0      0     373450   8.0500   NaN        S
# 2   NaN      0      0     330877   8.4583   NaN        Q
# 3  54.0      0      0      17463  51.8625   E46        S
# 4   2.0      3      1     349909  21.0750   NaN        S

# %% [markdown]
# ##### - .set_index()
# > 特定のカラムをindexにする

# %%
# Nameをindexにしたい
df2 = df2.set_index('Name')
df2
# Out:
#                                 index  PassengerId  Survived  Pclass   Sex  \
# Name
# Braund, Mr. Owen Harris             0            1         0       3  male
# Allen, Mr. William Henry            4            5         0       3  male
# Moran, Mr. James                    5            6         0       3  male
# McCarthy, Mr. Timothy J             6            7         0       1  male
# Palsson, Master. Gosta Leonard      7            8         0       3  male
# ...                               ...          ...       ...     ...   ...
# Banfield, Mr. Frederick James     883          884         0       2  male
# Sutehall, Mr. Henry Jr            884          885         0       3  male
# Montvila, Rev. Juozas             886          887         0       2  male
# Behr, Mr. Karl Howell             889          890         1       1  male
# Dooley, Mr. Patrick               890          891         0       3  male
#
#                                  Age  SibSp  Parch            Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris         22.0      1      0         A/5 21171   7.2500
# Allen, Mr. William Henry        35.0      0      0            373450   8.0500
# Moran, Mr. James                 NaN      0      0            330877   8.4583
# McCarthy, Mr. Timothy J         54.0      0      0             17463  51.8625
# Palsson, Master. Gosta Leonard   2.0      3      1            349909  21.0750
# ...                              ...    ...    ...               ...      ...
# Banfield, Mr. Frederick James   28.0      0      0  C.A./SOTON 34068  10.5000
# Sutehall, Mr. Henry Jr          25.0      0      0   SOTON/OQ 392076   7.0500
# Montvila, Rev. Juozas           27.0      0      0            211536  13.0000
# Behr, Mr. Karl Howell           26.0      0      0            111369  30.0000
# Dooley, Mr. Patrick             32.0      0      0            370376   7.7500
#
#                                Cabin Embarked
# Name
# Braund, Mr. Owen Harris          NaN        S
# Allen, Mr. William Henry         NaN        S
# Moran, Mr. James                 NaN        Q
# McCarthy, Mr. Timothy J          E46        S
# Palsson, Master. Gosta Leonard   NaN        S
# ...                              ...      ...
# Banfield, Mr. Frederick James    NaN        S
# Sutehall, Mr. Henry Jr           NaN        S
# Montvila, Rev. Juozas            NaN        S
# Behr, Mr. Karl Howell           C148        C
# Dooley, Mr. Patrick              NaN        Q
#
# [577 rows x 12 columns]

# %% [markdown]
# ### 14: DataFrameの欠損値NaNに対応

# %% [markdown]
# #### | DataFrameのNaNについて
#
# >```復習```
# >
# > + NaNは`Not A Number`の略
# > + np.nanと同じ
# > + NaN判定には np.isnan() を使う(後述: pd.isna()もあります．)
# > + Noneとは別物
# > + DataFrameでは基本NaNが使われる．
# >
# > ちなみに， csvやエクセルで値が空白だと読み込んだ時にNaNになります．Noneではないことに注意!!!

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('input/train.csv')
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### | DataFrameのNaN用の関数

# %% [markdown]
# ##### - .dropna()
# > デフォルト axis=0 : NaNのあるレコード(行)を落とす<br>
# > axis=1 を引数にいれるとNaNを含むカラム(列)をdrop
#
# >```memo```
# >
# > モデルを組む際に， データ数を減らさずにデータを説明する変数(説明変数)を減らす作戦のときに使いますが，<br>
# > 「NaNが一つでもあるのでその説明変数を減らす」ということはまずありません．<br>
# > どの説明変数がモデル構築に重要なのかというのは非常に重要かつ慎重に考えるべき問題です．

# %%
df.dropna().tail()
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                          Carlsson, Mr. Frans Olof    male  33.0      0
# 879     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                      Graham, Miss. Margaret Edith  female  19.0      0
# 889                             Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket     Fare        Cabin Embarked
# 871      1   11751  52.5542          D35        S
# 872      0     695   5.0000  B51 B53 B55        S
# 879      1   11767  83.1583          C50        C
# 887      0  112053  30.0000          B42        S
# 889      0  111369  30.0000         C148        C

# %%
# 特定カラムのNaNのレコードだけ！ (実行業務頻出)
# リスト形式で渡すので注意． たとえ一つのカラムでも， リストで囲って渡す
df.dropna(subset=['Age'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %% [markdown]
# ##### - .fillna(value)
# > NaNに特定のvalueを代入

# %%
df.fillna('This is it!').tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex          Age  SibSp  Parch      Ticket   Fare        Cabin  \
# 886    male           27      0      0      211536  13.00  This is it!
# 887  female           19      0      0      112053  30.00          B42
# 888  female  This is it!      1      2  W./C. 6607  23.45  This is it!
# 889    male           26      0      0      111369  30.00         C148
# 890    male           32      0      0      370376   7.75  This is it!
#
#     Embarked
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
# AgeのカラムのNaNだけ、Ageの平均値を代入 
df['Age'].fillna(df['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.000000      0      0      211536  13.00   NaN        S
# 887  female  19.000000      0      0      112053  30.00   B42        S
# 888  female  29.699118      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.000000      0      0      111369  30.00  C148        C
# 890    male  32.000000      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ##### - pd.isna()
#
# > ```復習```
# >
# > np.isnan() で， DataFrameの全ての値のNaNの判定が可能です．<br>
# > しかし, np.isnan() だといちいちループで回さないといけないですし， stringsを入れるとエラーになったり， 使い勝手が悪いです．<br>
# > そこで, DataFrameの中の値のNaN判定には pd.isna() を使うといいです．<br>
# > (pd.isnull() も同じです． 最近名前が変わって pd.isna() が実装されました．特に理由がなければ pd.isna() を使いましょう．np.isnanと違って最後のnがないので注意です．)

# %%
df2 = pd.read_csv('input/train.csv')
pd.isna(df2).tail()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False

# %% [markdown]
# Seriesに対してよく使いますね．NaN判定の結果を別カラムで持ちたい時とか↓

# %%
#　Cabin_nanカラムを使いして，CabinのNaN判定結果を代入する
df2['Cabin_nan'] = pd.isna(df2['Cabin'])
df2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  Cabin_nan
# 886    male  27.0      0      0      211536  13.00   NaN        S       True
# 887  female  19.0      0      0      112053  30.00   B42        S      False
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S       True
# 889    male  26.0      0      0      111369  30.00  C148        C      False
# 890    male  32.0      0      0      370376   7.75   NaN        Q       True

# %% [markdown]
# ### 15: DataFrameのgroupby

# %% [markdown]
# #### | groupby

# %% [markdown]
# ##### - .groupby().関数()

# %%
import pandas as pd
df = pd.read_csv('input/train.csv')

# %%
# Pclassでgroupby
df.groupby('Pclass').mean() # .sum() .count() .descrive()等々使える
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df.groupby("Age").mean()
# Out:
#        PassengerId  Survived  Pclass  SibSp  Parch      Fare
# Age
# 0.42         804.0       1.0     3.0    0.0    1.0    8.5167
# 0.67         756.0       1.0     2.0    1.0    1.0   14.5000
# 0.75         557.5       1.0     3.0    2.0    1.0   19.2583
# 0.83         455.5       1.0     2.0    0.5    1.5   23.8750
# 0.92         306.0       1.0     1.0    1.0    2.0  151.5500
# ...            ...       ...     ...    ...    ...       ...
# 70.00        709.5       0.0     1.5    0.5    0.5   40.7500
# 70.50        117.0       0.0     3.0    0.0    0.0    7.7500
# 71.00        295.5       0.0     1.0    0.0    0.0   42.0792
# 74.00        852.0       0.0     3.0    0.0    0.0    7.7750
# 80.00        631.0       1.0     1.0    0.0    0.0   30.0000
#
# [88 rows x 6 columns]

# %%
# 試しに、階級１をフィルタリングして統計量を算出
df[df['Pclass'] == 1].describe()
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   216.000000  216.000000   216.0  186.000000  216.000000  216.000000
# mean    461.597222    0.629630     1.0   38.233441    0.416667    0.356481
# std     246.737616    0.484026     0.0   14.802856    0.611898    0.693997
# min       2.000000    0.000000     1.0    0.920000    0.000000    0.000000
# 25%     270.750000    0.000000     1.0   27.000000    0.000000    0.000000
# 50%     472.000000    1.000000     1.0   37.000000    0.000000    0.000000
# 75%     670.500000    1.000000     1.0   49.000000    1.000000    0.000000
# max     890.000000    1.000000     1.0   80.000000    3.000000    4.000000
#
#              Fare
# count  216.000000
# mean    84.154687
# std     78.380373
# min      0.000000
# 25%     30.923950
# 50%     60.287500
# 75%     93.500000
# max    512.329200

# %%
# 更に、meanにフォーカスしたいので、
df[df['Pclass'] == 1].describe().loc['mean']
# Out:
# PassengerId    461.597222
# Survived         0.629630
# Pclass           1.000000
# Age             38.233441
# SibSp            0.416667
# Parch            0.356481
# Fare            84.154687
# Name: mean, dtype: float64

# %%
# 当然これもDataFrameなので．以下のようにカラムを指定して取り出すことができます．
df.groupby('Pclass').describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std   min     25%    50%    75%    max
# Pclass
# 1            216.0  461.597222  246.737616   2.0  270.75  472.0  670.5  890.0
# 2            184.0  445.956522  250.852161  10.0  234.50  435.5  668.0  887.0
# 3            491.0  439.154786  264.441453   1.0  200.00  432.0  666.5  891.0
#
#        Survived            ... Parch        Fare                             \
#           count      mean  ...   75%  max  count       mean        std  min
# Pclass                     ...
# 1         216.0  0.629630  ...   0.0  4.0  216.0  84.154687  78.380373  0.0
# 2         184.0  0.472826  ...   1.0  3.0  184.0  20.662183  13.417399  0.0
# 3         491.0  0.242363  ...   0.0  6.0  491.0  13.675550  11.778142  0.0
#
#
#              25%      50%   75%       max
# Pclass
# 1       30.92395  60.2875  93.5  512.3292
# 2       13.00000  14.2500  26.0   73.5000
# 3        7.75000   8.0500  15.5   69.5500
#
# [3 rows x 48 columns]

# %%
df.groupby('Pclass').describe()['Age']
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Pclass
# 1       186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0
# 2       173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0
# 3       355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0

# %% [markdown]
# ##### - set_option()

# %% [markdown]
# >```Python
# ># カラムを省略せずに表示
# >pd.set_option('display.max_columns', None)
# ># 行を省略せずに表示
# >pd.set_option('display.max_rows', None)
# >```
#
# 戻し方

# %% [markdown]
# #### | (上級者向け) groupbyの結果をfor文でまわす
#
# > `.groupby()`の結果はfor文で回すことができ，(index, groupbyされたDataFrame)のタプルの形で回せます．<br>
# > どういうことかというと以下の例をみてください． <br>
# > i と group_df にはそれぞれ1, 2, 3および Pclass==1, ==2, ==3でフィルタされたときのDataFrameが格納されています．<br>
# > （例として len() で各DataFrameのレコード数を表示してます．）

# %%
for i, group_df in df.groupby('Pclass'):
    print("{}: group_df's type is {} and has {}".format(i, type(group_df), len(group_df)))
# Out:
# 1: group_df's type is <class 'pandas.core.frame.DataFrame'> and has 216
# 2: group_df's type is <class 'pandas.core.frame.DataFrame'> and has 184
# 3: group_df's type is <class 'pandas.core.frame.DataFrame'> and has 491

# %%
# 各Pclassのグループの中で，各レコードが何番目にFareが高いか数字を振ってみ
df = pd.read_csv('input/train.csv')
results = []
for i, group_df in df.groupby('Pclass'):
    sorted_group_df = group_df.sort_values('Fare')
    sorted_group_df['RankInPClass'] = np.arange(len(sorted_group_df))
    results.append(sorted_group_df)
result_df = pd.concat(results)
result_df
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 633          634         0       1      Parr, Mr. William Henry Marsh    male
# 822          823         0       1    Reuchlin, Jonkheer. John George    male
# 815          816         0       1                   Fry, Mr. Richard    male
# 806          807         0       1             Andrews, Mr. Thomas Jr    male
# 263          264         0       1              Harrison, Mr. William    male
# ..           ...       ...     ...                                ...     ...
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 201          202         0       3                Sage, Mr. Frederick    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked  RankInPClass
# 633   NaN      0      0    112052   0.00   NaN        S             0
# 822  38.0      0      0     19972   0.00   NaN        S             1
# 815   NaN      0      0    112058   0.00  B102        S             2
# 806  39.0      0      0    112050   0.00   A36        S             3
# 263  40.0      0      0    112059   0.00   B94        S             4
# ..    ...    ...    ...       ...    ...   ...      ...           ...
# 180   NaN      8      2  CA. 2343  69.55   NaN        S           486
# 863   NaN      8      2  CA. 2343  69.55   NaN        S           487
# 846   NaN      8      2  CA. 2343  69.55   NaN        S           488
# 201   NaN      8      2  CA. 2343  69.55   NaN        S           489
# 792   NaN      8      2  CA. 2343  69.55   NaN        S           490
#
# [891 rows x 13 columns]

# %% [markdown]
# ### 16: DataFrameのテーブル結合

# %% [markdown]
# #### | 表の結合とは？
#
# > + 特定のカラムやindexをKeyにして結合する
# > + DataFrameを単純に横に(もしくは縦に)結合する（ガッチャンコさせる）
# >
# > mergeとconcatでは圧倒的にmergeの方が出てきます．<br>
# > mergeもconcatも元のDataFrameを更新しないので，<br>
# > 新たな変数か元の変数に再代入する必要あり

# %%
import pandas as pd
df1 = pd.DataFrame({ 'Key': ['k0', 'k1', 'k2'],
        'A': ['a0', 'a1', 'a2'],
        'B': ['b0', 'b1', 'b2']})

df2 = pd.DataFrame({ 'Key': ['k0', 'k1', 'k2'],
        'C': ['c0', 'c1', 'c2'],
        'D': ['d0', 'd1', 'd2']})

# %% [markdown]
# ##### - df.merge()

# %%
# 特定のカラムやindexをKeyにして結合する
df1.merge(df2)
# Out:
#   Key   A   B   C   D
# 0  k0  a0  b0  c0  d0
# 1  k1  a1  b1  c1  d1
# 2  k2  a2  b2  c2  d2

# %% [markdown]
# ##### - pd.concat()
# > concatenateの略

# %%
# DataFrameを単純に横に(もしくは縦に)結合する（ガッチャンコさせる）
# 縦
pd.concat([df1, df2], axis=0)
# Out:
#   Key    A    B    C    D
# 0  k0   a0   b0  NaN  NaN
# 1  k1   a1   b1  NaN  NaN
# 2  k2   a2   b2  NaN  NaN
# 0  k0  NaN  NaN   c0   d0
# 1  k1  NaN  NaN   c1   d1
# 2  k2  NaN  NaN   c2   d2

# %%
# 横
pd.concat([df1, df2], axis=1)
# Out:
#   Key   A   B Key   C   D
# 0  k0  a0  b0  k0  c0  d0
# 1  k1  a1  b1  k1  c1  d1
# 2  k2  a2  b2  k2  c2  d2

# %% [markdown]
# #### | .merge()の使い方をマスタ-
#
#
#
# <img src='https://datawokagaku.com/wp-content/uploads/2020/02/params_merge-300x241.png' width=35%>
#
# 重要な引数：
# > + how : どう結合するか→{‘left’, ‘right’, ‘outer’, ‘inner’}, デフォルトは ‘inner’
# > + on : keyにするカラムを指定（どちらのDataFrameにも存在するカラム）．指定をしないと共通のカラムで結合される
# > + left_on：leftのDataFrameのkeyにするカラム
# > + right_on：rightのDataFrameのkeyにするカラム
# > + left_index：leftのKeyをindexにする場合Trueを指定
# > + right_index：rightのKeyをindexにする場合Trueを指定

# %% [markdown]
# ##### - merge(how='') left right

# %%
df1 = pd.DataFrame({
                'Key': ['k0', 'k1', 'k2'],
                'A': ['a0', 'a1', 'a2'],
                'B': ['b0', 'b1', 'b2']})

df2 = pd.DataFrame({
                'Key': ['k0', 'k1', 'k3'],
                'C': ['c0', 'c1', 'c3'],
                'D': ['d0', 'd1', 'd3']})

# %%
df１
# Out:
#   Key   A   B
# 0  k0  a0  b0
# 1  k1  a1  b1
# 2  k2  a2  b2

# %%
df2
# Out:
#   Key   C   D
# 0  k0  c0  d0
# 1  k1  c1  d1
# 2  k3  c3  d3

# %%
# df1:left df2:right
# rightの表には’k2’がありません． なので’k2’のC, DはNaNが入ります．leftの表のレコードは失われないイメージ
df1.merge(df2, how='left')
# Out:
#   Key   A   B    C    D
# 0  k0  a0  b0   c0   d0
# 1  k1  a1  b1   c1   d1
# 2  k2  a2  b2  NaN  NaN

# %% [markdown]
# ##### - merge(how='') outer

# %%
# left(df1)もright(df2)もどちらもレコードを失うことなく， 結合できるレコードは結合(以外はNaNで埋める)
df1.merge(df2, how='outer')
# Out:
#   Key    A    B    C    D
# 0  k0   a0   b0   c0   d0
# 1  k1   a1   b1   c1   d1
# 2  k2   a2   b2  NaN  NaN
# 3  k3  NaN  NaN   c3   d3

# %% [markdown]
# ##### - merge(how='') inner

# %%
# left(df1)もright(df2)にもある共通のレコードだけ
df1.merge(df2, how='inner')
# Out:
#   Key   A   B   C   D
# 0  k0  a0  b0  c0  d0
# 1  k1  a1  b1  c1  d1

# %% [markdown]
# ##### - merge(on='')

# %%
df1 = pd.DataFrame({ 
                'Key': ['k0', 'k1', 'k2'],
                'ID': ['aa', 'bb', 'cc'],
                'A': ['a0', 'a1', 'a2'],
                'B': ['b0', 'b1', 'b2']})

df2 = pd.DataFrame({ 
                'Key': ['k0', 'k1', 'k3'],
                'ID': ['aa', 'bb', 'cc'],
                'C': ['c0', 'c1', 'c3'],
                'D': ['d0', 'd1', 'd3']})

# %%
df1
# Out:
#   Key  ID   A   B
# 0  k0  aa  a0  b0
# 1  k1  bb  a1  b1
# 2  k2  cc  a2  b2

# %%
df2
# Out:
#   Key  ID   C   D
# 0  k0  aa  c0  d0
# 1  k1  bb  c1  d1
# 2  k3  cc  c3  d3

# %%
# KeyカラムをKeyにして結合
df1.merge(df2, on='Key')
# Out:
#   Key ID_x   A   B ID_y   C   D
# 0  k0   aa  a0  b0   aa  c0  d0
# 1  k1   bb  a1  b1   bb  c1  d1

# %%
# IDカラムをKeyにして結合
df1.merge(df2, on='ID')
# Out:
#   Key_x  ID   A   B Key_y   C   D
# 0    k0  aa  a0  b0    k0  c0  d0
# 1    k1  bb  a1  b1    k1  c1  d1
# 2    k2  cc  a2  b2    k3  c3  d3

# %%
# suffixesを指定する
df1.merge(df2, on='ID', suffixes=('_left', '_right'))
# Out:
#   Key_left  ID   A   B Key_right   C   D
# 0       k0  aa  a0  b0        k0  c0  d0
# 1       k1  bb  a1  b1        k1  c1  d1
# 2       k2  cc  a2  b2        k3  c3  d3

# %% [markdown]
# ##### - merge(left_on='', right_on='')

# %%
df1 = pd.DataFrame({ 'Key1': ['k0', 'k1', 'k2'],
                    'A': ['a0', 'a1', 'a2'],
                    'B': ['b0', 'b1', 'b2']})

df2 = pd.DataFrame({ 'Key2': ['k0', 'k1', 'k3'],
                    'C': ['c0', 'c1', 'c3'],
                    'D': ['d0', 'd1', 'd3']})

# %%
df1
# Out:
#   Key1   A   B
# 0   k0  a0  b0
# 1   k1  a1  b1
# 2   k2  a2  b2

# %%
df2
# Out:
#   Key2   C   D
# 0   k0  c0  d0
# 1   k1  c1  d1
# 2   k3  c3  d3

# %%
# suffixesを指定する
df1.merge(df2, left_on='Key1', right_on='Key2')
# Out:
#   Key1   A   B Key2   C   D
# 0   k0  a0  b0   k0  c0  d0
# 1   k1  a1  b1   k1  c1  d1

# %% [markdown]
# ##### - merge(left_index='', right_index='')

# %%
df1.merge(df2, left_index=True, right_index=True)
# Out:
#   Key1   A   B Key2   C   D
# 0   k0  a0  b0   k0  c0  d0
# 1   k1  a1  b1   k1  c1  d1
# 2   k2  a2  b2   k3  c3  d3

# %% [markdown]
# ##### - .join()
#
# > ```memo```
# >
# > 複数のDataFrameを一気に連結できます．<br>
# > が...これはオススメしません．バグのもとになりやすいですし，コードが読みにくくなります．<br>
# > できれば一つ一つ結合することをオススメします．

# %%
df1 = pd.DataFrame({ 'Key1': ['k0', 'k1', 'k2'],
                    'A': ['a0', 'a1', 'a2'],
                    'B': ['b0', 'b1', 'b2']})

df2 = pd.DataFrame({ 'Key2': ['k0', 'k1', 'k3'],
                    'C': ['c0', 'c1', 'c3'],
                    'D': ['d0', 'd1', 'd3']})
df3 = pd.DataFrame({ 'Key3': ['k0', 'k1', 'k4'],
                    'E': ['c0', 'c1', 'c3'],
                    'F': ['d0', 'd1', 'd3']})

df1.join([df2, df3])
# Out:
#   Key1   A   B Key2   C   D Key3   E   F
# 0   k0  a0  b0   k0  c0  d0   k0  c0  d0
# 1   k1  a1  b1   k1  c1  d1   k1  c1  d1
# 2   k2  a2  b2   k3  c3  d3   k4  c3  d3

# %% [markdown]
# ### 17: DataFrameの重要関数(apply, unique, value_counts)

# %% [markdown]
# ##### - .unique() .nunique()
# > Seriesの関数です．よく使います．
# > 「このカラムはどんな値を保持するんだろう？」と思いますよね？<br>
# > 例えば「本当にPclassは1, 2, 3しか値がないのだろうか？」と思うことがあると思います． <br>
# > そういうときにこれらの関数を使います．

# %%
import pandas as pd
df = pd.read_csv('input/train.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass'].nunique()
# Out:
# 3

# %% [markdown]
# ##### - .value_counts()
# > それぞれの値に対していくつのレコードがあるのかをSeries形式で返してくれます．

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# #### | .apply（）

# %% [markdown]
# ##### - (超重要).apply()
# > apply : 適用
# >
# >     基本的にDataFrameの操作はapply関数で処理していくと言っていいと思います．
# >     apply()関数を使って， DataFrameの全てのレコードに処理をして， その結果を別のカラムに格納することができます．
#
# <img src='https://datawokagaku.com/wp-content/uploads/2020/02/apply_overview-1.png' width=45%>

# %%
def get_age_group(age):
    return str(age)[0] + '0s'

# 実行
get_age_group(45)
# Out:
# '40s'

# %%
df = pd.DataFrame({ 
     'name': ['john', 'Mike', 'Emily'],
     'age': ['23', '36', '42']
})
df
# Out:
#     name age
# 0   john  23
# 1   Mike  36
# 2  Emily  42

# %%
df['age'].apply(get_age_group)
# Out:
# 0    20s
# 1    30s
# 2    40s
# Name: age, dtype: object

# %%
# 'age_group'カラムを新たに作り，結果を代入
df['age_group'] = df['age'].apply(get_age_group)
df
# Out:
#     name age age_group
# 0   john  23       20s
# 1   Mike  36       30s
# 2  Emily  42       40s

# %% [markdown]
# ##### - lambda関数を使った.apply()

# %%
# lambda関数を変数fに代入して
f = lambda x: str(x)[0] + '0s'
#　試しに43を入れてみる
f(43)
# Out:
# '40s'

# %%
df['age_group'] = df['age'].apply(lambda x: str(x)[0] + '0s')
df
# Out:
#     name age age_group
# 0   john  23       20s
# 1   Mike  36       30s
# 2  Emily  42       40s

# %% [markdown]
# ##### - レコード全体に対し.apply()
# > 行に対してapplyする場合，axis=1を指定する必要があります．

# %%
df = pd.DataFrame({ 'name': ['john', 'Mike', 'Emily'],
                    'age': ['23', '36', '42']})
df['description'] = df.apply(lambda row: '{} is {} years old'.format(row['name'], row['age']), axis=1)
df
# Out:
#     name age            description
# 0   john  23   john is 23 years old
# 1   Mike  36   Mike is 36 years old
# 2  Emily  42  Emily is 42 years old

# %% [markdown]
# ### 18: DataFrameのその他頻出関数(to_csv, iterrows, sort_values)

# %% [markdown]
# ##### - df.to_csv()

# %%
import pandas as pd
df = pd.read_csv('input/train.csv')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df['Adult'] = df['Age'].apply(lambda x : x > 20)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Adult
# 0      0         A/5 21171   7.2500   NaN        S   True
# 1      0          PC 17599  71.2833   C85        C   True
# 2      0  STON/O2. 3101282   7.9250   NaN        S   True
# 3      0            113803  53.1000  C123        S   True
# 4      0            373450   8.0500   NaN        S   True

# %%
df.to_csv('output/train_w_aduld.csv')

# %% [markdown]
# ```python
# df.to_csv('../../../../train_w_adult.csv')
# ```

# %%
df_new = pd.read_csv('output/train_w_aduld.csv')
display(df_new)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Adult
# 0        0         A/5 21171   7.2500   NaN        S   True
# 1        0          PC 17599  71.2833   C85        C   True
# 2        0  STON/O2. 3101282   7.9250   NaN        S   True
# 3        0            113803  53.1000  C123        S   True
# 4        0            373450   8.0500   NaN        S   True
# ..     ...               ...      ...   ...      ...    ...
# 886      0            211536  13.0000   NaN        S   True
# 887      0            112053  30.0000   B42        S  False
# 888      2        W./C. 6607  23.4500   NaN        S  False
# 889      0            111369  30.0000  C148        C   True
# 890      0            370376   7.7500   NaN        Q   True
#
# [891 rows x 14 columns]

# %% [markdown]
# >    ```Unnamed:```と謎のカラムが作成される
# >     これは、indexeがそのまま保存されている。pandasで読み込むたびに生成されるのは不要
# >     オプションを付するればOK
# >
#
# > ```Python
# > df.to_csv('pass.csv', index=False)
# > ```

# %% [markdown]
# ##### - .iterrows()
# >     DataFrameをfor文でイテレーションするときに使います．
# >     覚えにくいですが，「rows」を「iteration」するのでiter + row + s. と覚えましょう

# %%
for idx, row in df.iterrows():
    if row['Age'] > 40 and row['Pclass'] == 3 and row['Sex'] == 'male' and row["Survived"] == 1:
        print("{}: {} is very luck guy...!".format(idx, row['Name']))
# Out:
# 338: Dahl, Mr. Karl Edwart is very luck guy...!
# 414: Sundman, Mr. Johan Julian is very luck guy...!

# %% [markdown]
# ##### - .sort_values()
# >     SeriesではなくDataFrameの関数であることに注意してください．
# >     デフォルトは昇順ソート(小→大)です．降順ソート(大→小)にするには ascending=False を指定します．

# %%
df.sort_values('Age', ascending=False) #降順指定
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Adult
# 630    male  80.0      0      0       27042  30.0000   A23        S   True
# 851    male  74.0      0      0      347060   7.7750   NaN        S   True
# 493    male  71.0      0      0    PC 17609  49.5042   NaN        C   True
# 96     male  71.0      0      0    PC 17754  34.6542    A5        C   True
# 116    male  70.5      0      0      370369   7.7500   NaN        Q   True
# ..      ...   ...    ...    ...         ...      ...   ...      ...    ...
# 859    male   NaN      0      0        2629   7.2292   NaN        C  False
# 863  female   NaN      8      2    CA. 2343  69.5500   NaN        S  False
# 868    male   NaN      0      0      345777   9.5000   NaN        S  False
# 878    male   NaN      0      0      349217   7.8958   NaN        S  False
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S  False
#
# [891 rows x 13 columns]

# %% [markdown]
# ### 19: DataFrameのその他頻出関数(pivot_table, xs)

# %% [markdown]
# ##### - pivot_table()
# > データサイエンスでは殆ど用いない。頭の片隅に置いておこう

# %%
import pandas as pd

# %%
data = {'Date':['Jan-1', 'Jan-1', 'Jan-1', 'Jan-2', 'Jan-2', 'Jan-2'], 
        'User':['Emily', 'John', 'Nick', 'Kevin', 'Emily', 'John'],
        'Method':['Card', 'Card', 'Cash', 'Card', 'Cash', 'Cash'],
        'Price':[100, 250, 200, 460, 200, 130]}
df = pd.DataFrame(data)
df
# Out:
#     Date   User Method  Price
# 0  Jan-1  Emily   Card    100
# 1  Jan-1   John   Card    250
# 2  Jan-1   Nick   Cash    200
# 3  Jan-2  Kevin   Card    460
# 4  Jan-2  Emily   Cash    200
# 5  Jan-2   John   Cash    130

# %%
df.pivot_table(values='Price', index=['Date', 'User'], columns=['Method'])
# Out:
# Method        Card   Cash
# Date  User
# Jan-1 Emily  100.0    NaN
#       John   250.0    NaN
#       Nick     NaN  200.0
# Jan-2 Emily    NaN  200.0
#       John     NaN  130.0
#       Kevin  460.0    NaN

# %%
pivot = df.pivot_table(values="Price", index=["Date", "User"], columns=["Method"])
pivot
# Out:
# Method        Card   Cash
# Date  User
# Jan-1 Emily  100.0    NaN
#       John   250.0    NaN
#       Nick     NaN  200.0
# Jan-2 Emily    NaN  200.0
#       John     NaN  130.0
#       Kevin  460.0    NaN

# %% [markdown]
# ##### .xs()
# > cross-section操作
# >
# >     これもあまり使いませんが，ピボットのような複数のindexをもったDataFrameを操作する際に重宝します．

# %%
pivot.loc["Jan-1"]
# Out:
# Method   Card   Cash
# User
# Emily   100.0    NaN
# John    250.0    NaN
# Nick      NaN  200.0

# %%
pivot.loc["Card"]
# Out:
# --------------------------------------
# KeyErrorTraceback (most recent call last)
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Card'
#
# The above exception was the direct cause of the following exception:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-116-a26bfe556e07> in <module>
# ----> 1 pivot.loc["Card"]
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3487         index = self.index
#    3488         if isinstance(index, MultiIndex):
# -> 3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
#    3491             loc = self.index.get_loc(key)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2883                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    2884         else:
# -> 2885             indexer = self._get_level_indexer(key, level=level)
#    2886             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    2887
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2967         else:
#    2968
# -> 2969             code = self._get_loc_single_level_index(level_index, key)
#    2970
#    2971             if level > 0 or self.lexsort_depth == 0:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2635             return -1
#    2636         else:
# -> 2637             return level_index.get_loc(key)
#    2638
#    2639     def get_loc(self, key, method=None):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Card'

# %%
pivot.xs("Card", level="Method")
# Out:
# --------------------------------------
# ValueErrorTraceback (most recent call last)
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_number(self, level)
#    1425         try:
# -> 1426             level = self.names.index(level)
#    1427         except ValueError as err:
#
# ValueError: 'Method' is not in list
#
# The above exception was the direct cause of the following exception:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-117-e703ed077e69> in <module>
# ----> 1 pivot.xs("Card", level="Method")
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3471             if not isinstance(labels, MultiIndex):
#    3472                 raise TypeError("Index must be a MultiIndex")
# -> 3473             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3474
#    3475             # create the tuple of the indexer
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2820             return result, maybe_mi_droplevels(result, level, drop_level)
#    2821
# -> 2822         level = self._get_level_number(level)
#    2823
#    2824         # kludge for #1796
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_number(self, level)
#    1427         except ValueError as err:
#    1428             if not is_integer(level):
# -> 1429                 raise KeyError(f"Level {level} not found") from err
#    1430             elif level < 0:
#    1431                 level += self.nlevels
#
# KeyError: 'Level Method not found'

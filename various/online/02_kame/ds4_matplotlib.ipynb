# %% [markdown]
# # matplotlib
# > `INDEX`
# > + [20 Data Visualization20 Data Visualization](#20-Data-Visualization)
# > + [21 subplotとオブジェクト指向を使って複数のグラフを並べる](#21-subplotとオブジェクト指向を使って複数のグラフを並べる)
# > + [22 グラフをPNG，PDFで保存](#22-グラフをPNG，PDFで保存)
# > + [23 色々なグラフを描画](#23-色々なグラフを描画)
#
# > `Cf.`
# > + [データサイエンスのためのPython入門20〜matplotlibを使ってData Visualizationを始めよう〜](https://datawokagaku.com/data_vis_intro/)
# > + [データサイエンスのためのPython入門21〜matplotlibのsubplotとオブジェクト指向を使って複数のグラフを並べる〜](https://datawokagaku.com/matplotlib_subplot/)
# > + [データサイエンスのためのPython入門22〜matplotlibを使ってグラフをPNG，PDFで保存する〜](https://datawokagaku.com/savefig_png_pdf/)
# > + [データサイエンスのためのPython入門23〜matplotlibで色々なグラフを描画する〜](https://datawokagaku.com/matplotlib_variousplots/)

# %% [markdown]
# ## 20 Data Visualization

# %% [markdown]
# ### | matplotlibをimportする

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### | matplotlibでplotしてみる

# %%
x = np.linspace(-3, 3, 10)
x
# Out:
# array([-3.        , -2.33333333, -1.66666667, -1.        , -0.33333333,
#         0.33333333,  1.        ,  1.66666667,  2.33333333,  3.        ])

# %%
y = np.exp(x)
y
# Out:
# array([ 0.04978707,  0.09697197,  0.1888756 ,  0.36787944,  0.71653131,
#         1.39561243,  2.71828183,  5.29449005, 10.3122585 , 20.08553692])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, "g^")

# %% [markdown]
# ### | 付属情報をつける
#
# + plt.xlabel()でx軸にラベルをつける
# + plt.ylabel()でy軸にラベルをつける
# + plt.title()で図にタイトルをつける
# + plt.plot(label=’ラベル’)でplotにラベルをつけ, plt.legend()で凡例をつける
# + plt.xticks()でx軸に任意のticksをつける(目盛り)
# + plt.yticks()でy軸に任意のticksをつける
# + plt.axis(‘off’)で軸を消す

# %%
plt.plot(x, y)
plt.xlabel('Effort') # plt.xlabel()でx軸にラベルをつける
plt.ylabel('Earning') # plt.ylabel()でy軸にラベルをつける
plt.title('This is how your effor earns') # plt.title()で図にタイトルをつける
# Out:
# Text(0.5, 1.0, 'This is how your effor earns')

# %%
# plt.plot(label='ラベル')でplotにラベルをつけ, plt.legend()で凡例をつける
plt.plot(x,y, label='Earning with effort')
plt.legend()
plt.xticks(np.arange(-3, 4, 0.5)) # plt.xticks()でx軸に任意のticksをつける
plt.yticks([0, 5, 10, 20]) # plt.yticks()でy軸に任意のticksをつける
# plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x11dc1ac70>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
x = np.linspace(-3, 3, 10)
y1 = np.exp(x)
y2 = np.exp(x)*2
plt.plot(x, y1, label='first')
plt.plot(x, y2, label='second')
plt.axis('off') #軸を消す
plt.legend()

# %% [markdown]
# ## 21 subplotとオブジェクト指向を使って複数のグラフを並べる

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### | subplotを使ってみる
# > `plt.plot()`の前に`plt.subplot(row, column, index)`を実行
# > `row X column`の箱が確保され，`index番目`にグラフが描画

# %%
x = np.linspace(-3, 3, 10)
y1 = np.exp(x)
y2 = x*x
print("x: ", x)
print("y1: ", y1)
print("y2: ", y2)
# Out:
# x:  [-3.         -2.33333333 -1.66666667 -1.         -0.33333333  0.33333333
#   1.          1.66666667  2.33333333  3.        ]
# y1:  [ 0.04978707  0.09697197  0.1888756   0.36787944  0.71653131  1.39561243
#   2.71828183  5.29449005 10.3122585  20.08553692]
# y2:  [9.         5.44444444 2.77777778 1.         0.11111111 0.11111111
#  1.         2.77777778 5.44444444 9.        ]

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y1)

plt.subplot(1, 2, 2)
plt.plot(x, y2)

# %% [markdown]
#     indexが0ではなく1から始まることに注意!!

# %% [markdown]
# ### | オブジェクト指向による記述(重要)

# %% [markdown]
# #### - plt.figure (オブジェクト)

# %%
# plt.figureクラスでfigというインスタンス作成
fig = plt.figure()
type(fig)
# Out:
# matplotlib.figure.Figure

# %% [markdown]
# ##### - fig.add_subplo()

# %%
fig = plt.figure(figsize=(4, 2))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.plot(x, y1)
ax2.plot(x, y2)

# %% [markdown]
# #### - plt.subplots()

# %% [markdown]
# ##### - 一次元 .subplots()

# %%
# 1行2列のplotを作成 axesにはそれぞれのaxesオブジェクトがリストで返される
fig, ax = plt.subplots(nrows=1, ncols=2)
ax
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].plot(x, y1)
ax[1].plot(x, y2)

# %% [markdown]
# ##### - 多次元 .subplots()
#     一点注意が必要なのは， subplots() のnrowsが2以上ある場合，
#     つまり2行以上のsubplotsを作る場合， axesは多次元arrayになります．
#     そのため，それぞれのaxesを使うためにはaxes[row_index, col_index]を指定します．

# %%
fig, ax = plt.subplots(nrows=3, ncols=3)
print(ax.shape)
# Out:
# (3, 3)

# %%
fig, ax = plt.subplots(nrows=3, ncols=3)
ax[1, 2].plot(x, y2) #1行2列にプロット

# %% [markdown]
# ### | オブジェクト指向で付属情報をつける
#
# オブジェクト指向では基本，`ax.set_xx()`の形で同様に付属情報を付け加えることができます．legend()とaxis(‘off’)はそのままaxesオブジェクトから同様コールします．

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, y1, label='something')
axes[1].plot(x, y1)
axes[0].set_xlabel('xlabel1')
axes[0].set_ylabel('xlabel2')
axes[0].set_title('plot title')
axes[0].set_xticks([-3, -2, -1, 3])
axes[0].set_yticks([0, 10, 20])
axes[0].legend()
axes[1].axis('off')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].plot(x, y1, label="something")
ax[1].plot(x, y1)
ax[0].set_xlabel("xlabel1")
ax[0].set_ylabel("xlabel2")
ax[0].set_title("plot title")
ax[0].set_xticks([-3, -2, -1, 3])
ax[0].set_yticks([0, 10, 20])
ax[0].legend()
ax[1].axis("off")
# Out:
# (-3.3, 3.3, -0.9520004243731263, 21.08732441592866)

# %% [markdown]
# ## 22 グラフをPNG，PDFで保存

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-3, 3, 10)
y1 = np.exp(x)
y2 = np.exp(x)*2
fig, axes = plt.subplots()
axes.plot(x, y1)

# %% [markdown]
# ### | グラフの大きさを調整

# %% [markdown]
# ##### - 引数dpiで画素指定
#     figsize引数とdpi引数を使ってグラフのサイズを変えてみましょう．
#     figsizeにはタプルで（横幅，高さ）をインチ数で指定します．
#     dpiというのは，　Dots per inch（1inchの中に何ドット入るかということ）．
#     つまり，　「figsizeで指定したインチ数」 x 「dpi」 がドット数.
#     実際にはdpiはデフォルトの値を使って， figsizeのみでサイズを変更します．

# %%
# この場合モニタで100画素 x 100画素のグラフが表示される
fig, axes = plt.subplots(figsize=(1, 1), dpi=100)
axes.plot(x, y1)

# %%
fig, ax = plt.subplots(figsize=(10, 3))
ax. plot(x, y1)

# %% [markdown]
# ### | pngで保存

# %% [markdown]
# ##### - .savefig()
# `一番手軽で一番使います`

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 3))
ax[0, ].plot(x, y1)
ax[0, ].set_title("first")
ax[0, ].set_xlabel("x")
ax[0, ].set_ylabel("y")

ax[1, ].plot(x, x*x)
ax[1, ].set_title("second")
ax[1, ].set_xlabel("x")
ax[1, ].set_ylabel("y")

# figureオブジェクトのsavefig()関数を呼ぶ
fig.savefig('output/savefig_sample1.png')

# %% [markdown]
# ##### - plt.tight_layout()
#     グラフを複数並べたりタイトル，軸のラベルをいれると，軸のラベルとタイトルがかぶったりして見にくくなります．
#     plt.tight_layout() をコールすることでこの辺をいい具合に調整．

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 3))
ax[0, ].plot(x, y1)
ax[0, ].set_title("first")
ax[0, ].set_xlabel("x")
ax[0, ].set_ylabel("y")

ax[1, ].plot(x, x*x)
ax[1, ].set_title("second")
ax[1, ].set_xlabel("x")
ax[1, ].set_ylabel("y")

#いい感じに調整
plt.tight_layout()
fig.savefig('output/savefig_sample2.png')

# %% [markdown]
# ### | pdfで保存

# %%
from matplotlib.backends.backend_pdf import PdfPages

pdf = PdfPages('output/savefig_sample.pdf')

# %% [markdown]
#     pdfインスタンスを通じて，このファイルにいろんなことができちゃう！という仕組みです．（オブジェクト指向すごい）

# %%
# PdfPagesをimport(覚える必要なし，コピペで使い回す)
from matplotlib.backends.backend_pdf import PdfPages
# pdfインスタンス作成．この時点でファイルができる
pdf = PdfPages('output/savefig_sample.pdf')

#------グラフ作成--------
fig, axes = plt.subplots()
axes.plot(x, y1, label='first')
axes.plot(x, y2, label='second')
axes.plot(x, y1+y2, label='first + second')
axes.legend(loc=0)
#-----------------------

#pdfに保存
pdf.savefig(fig)

#close処理（一応やる）
pdf.close()

# %% [markdown]
# ### | 大量のグラフをpdfで保存

# %%
pdf = PdfPages('savemultifig_sample.pdf')
for i in range(0, 10):
    #------グラフ作成--------
    fig, axes = plt.subplots()
    #グラフの形状が徐々にかわるように設計しました．（適当です．）
    axes.plot(x, y1 + x*i)
    #タイトルをつけます．pdfで文字検索ができることを確認してください．
    axes.set_title('ID:#{}'.format(i))
    #-----------------------

    #forループのなかで保存
    pdf.savefig(fig)

#ループ後に閉じます
pdf.close()

# %% [markdown]
#     savemultifig_sample.pdfが保存されていると思います．
#     そのpdfを開いてみてください．1ページに１グラフ描画されているはずです．
#     試しにctrl+Fで「#4」と検索してみてください．ID#4のグラフにすぐに飛べます．
#
#     これ，すごく便利なんですよね・・・特に画像を扱っていると1000枚くらいの画像やその関連グラフを一気にfor文で回してこのように一つのpdfにすることができます．
#     しかも文字列検索ができるので必要なデータにすぐアクセスできます．
#     ぜひ業務で使ってみてください！(データが大きすぎるとpdfが壊れてしまうこともあるようです．その辺のサジ加減は適度に・・・)|

# %% [markdown]
# ## 23 色々なグラフを描画

# %% [markdown]
# ### |グラフ装飾の仕方

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#先ずは基本のおさらい
x = np.linspace(-3, 3, 10)
y = np.exp(x)
plt.plot(x, y)

# %% [markdown]
# ※どんな引数があるか、Jupyterの便利機能`shift + Tab`をみて確認してみよう
#
#     （全部貼り付けはスペース取るからざっくり列挙）
#     color : グラフの線の色　⇨　’red’や’green’のように色の名前を指定します．’r’や’g’のように頭文字でもOKです．
#     lw (line width) : 線の太さ　⇨　数字です．好みの大きさにしてください
#     ls (line style) : 線の種類　⇨　’-‘や’--‘のように指定します．よく使うのはこの二つのどちらかです．
#     marker : マーカーの種類　⇨　’o’や’x’ように指定します．マーカーの形が変わります．
#     markersize : マーカーの大きさ　⇨　数字です．好みの大きさにしてください
#     markerfacecolor : マーカーの色　⇨　’red’や’green’のように色の名前を指定します．’r’や’g’のように頭文字でもOKです．
#     markeredgecolor : マーカーの枠に色　⇨　’red’や’green’のように色の名前を指定します．’r’や’g’のように頭文字でもOKです．
#     markeredgewidth : マーカーの枠の太さ　⇨　数字です．好みの大きさにしてください
#     alpha : plotの透明度　⇨　0から1の間をfloatで指定します．0に近い程透明度が上がります．

# %%
plt.plot(x, y, 
         #赤点線設定
         color='red', lw=5, ls='--', 
         #各ポイント設定
         marker='o', 
         markersize=15, 
         markerfacecolor='yellow', 
         markeredgecolor='blue', 
         markeredgewidth=4, 
         alpha=0.5)

# %% [markdown]
# ### |散布図：plt.scatter()

# %%
import pandas as pd
df = pd.read_csv('input/train.csv')

# %%
plt.scatter(df['Age'], df['Fare'], alpha=0.3 )
plt.title('Taitanick')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid(True)

# %% [markdown]
# ### |ヒストグラム : plt.hist()

# %%
plt.hist(df['Age'], bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### |箱ひげ図 : plt.boxplot()

# %%
df = df.dropna(subset=['Age'])
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Boxplotjはデリケートだから、NaNを除去してからじゃないとエラーが起きる
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11eb4df10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11eb65fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11eb61a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x11eb4f550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11f46a580>],
#  'means': []}

# %% [markdown]
# <img src='https://datawokagaku.com/wp-content/uploads/2020/02/boxplot_explain-1024x409.png' width=45%>
#
#     ひげの端をどうするかとか，外れ値を表示するかとか，箱の形，幅が違うとか，色々な変種がありますが，基本はこれです．
#     第3四分位点(Q3) – 第1四分位点(Q1)のこと（つまりbox plotの箱の高さ）をIQRといいますが，
#     ひげの端は Q1-1.5*IQR と Q3+1.5*IQR になってます．
#
#     1.5というのはデフォルトの値で，whis引数で変更が可能です．ただ，今はあまり気にしなくていいと思います．
